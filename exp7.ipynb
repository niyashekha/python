# %%
#print colors in set1 Not in set 2
s1=set(input("Enter the colors:").split(","))
s2=set(input("Enter the colors:").split(","))
print("colors in set1 but not in set2 : ",s1-s2)
# Out:
# Enter the colors: red,blue,green,yellow
# Enter the colors: blue,black,brown
# colors in set1 but not in set2 {'green', 'yellow', 'red'}

# %%
name=input("enter your name:")
print("Hello",name)
# Out:
# enter your name: Niya Shekha
# Hello Niya Shekha

# %%
name=input("Enter your name:")
print("Hello",name)
print(type(name))
# Out:
# Enter your name: Niya Shekha
# Hello Niya Shekha
# <class 'str'>

# %%
age=input("enter your age:")
print("Hello",age)
print(type(age))
# Out:
# enter your age: 20
# Hello 20
# <class 'str'>

# %%
n1=int(input("Enter First Number:"))
n2=int(input("Enter Second number:"))
sum=n1+n2
print("sum=",sum)
# Out:
# Enter First Number: 40
# Enter Second number: 60
# sum= 100

# %%
#square root of a number
import math
number=int(input("Enter a Number:"))
result=round(math.sqrt(number),2)
print(result)
# Out:
# Enter a Number: 34
# 5.83
